# %%
# Out:
#   category  S2_srw_1  S2_srw_2  S2_srw_3  S2_srw_4  S2_srw_5  S2_srw_6  \
# 0   forest    0.1601    0.2375    0.1011    0.1641    0.3235    0.3295
# 1      tea    0.1669    0.2689    0.1011    0.1912    0.4362    0.4444
# 2      tea    0.1992    0.2977    0.1011    0.1783    0.3951    0.4032
# 3      tea    0.1590    0.2605    0.1011    0.2002    0.4599    0.4679
# 4      tea    0.1599    0.2598    0.1011    0.1958    0.4520    0.4589
#
#    S2_srw_7  S2_srw_8  S2_srw_9  S2_srw_10  S2_srw_11
# 0    0.2809    0.1820    0.1574     0.1754     0.1921
# 1    0.3682    0.2084    0.1557     0.1918     0.1945
# 2    0.3442    0.1986    0.1654     0.1853     0.1955
# 3    0.3836    0.2054    0.1556     0.1934     0.1932
# 4    0.3820    0.2033    0.1546     0.1904     0.1938

# %%
import pandas as pd

df=pd.read_csv("/home/drdc/Documents/repos/pestsens-rw/1_orginal/df.csv")
df.head()

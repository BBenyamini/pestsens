# %% [markdown]
# # Reading files in python.
#
# In this jupyter notebook, we will explore different type of reading data in python environment
#
# we will explore context manager, numpy, and pandas ways of reading data

# %%
# Load CSV Using Python Standard Library
import csv
import numpy
import pandas as pd
url = 'https://github.com/BBenyamini/pestsens/blob/main/2_processed/df.csv'
# Load CSV using Pandas from URL

data = pd.read_csv(url, error_bad_lines=False)
print(data.shape)

# %%
import pandas as pd

df=pd.read_csv("/home/drdc/Documents/repos/pestsens/2_processed/df_all.csv")
df.head()
# Out:
#    fid  S2_srw_1  S2_srw_2  S2_srw_3  S2_srw_4  S2_srw_5  S2_srw_6  S2_srw_7  \
# 0    1    0.1743    0.2543    0.1011    0.1786    0.3251    0.3460    0.3085
# 1    2    0.1743    0.2543    0.1011    0.1786    0.3330    0.3460    0.3085
# 2    3    0.1928    0.2613    0.1011    0.1786    0.3044    0.3286    0.2948
# 3    4    0.1928    0.2613    0.1011    0.1786    0.2935    0.3286    0.2948
# 4    5    0.1783    0.2541    0.1012    0.1723    0.3059    0.3176    0.2865
#
#    S2_srw_8  S2_srw_9  S2_srw_10  S2_srw_11          x        y
# 0    0.2010    0.1622     0.1809     0.1985  29.026678 -2.39702
# 1    0.2010    0.1702     0.1890     0.1999  29.026768 -2.39702
# 2    0.2109    0.1871     0.1909     0.2010  29.026858 -2.39702
# 3    0.2109    0.1953     0.1919     0.2036  29.026947 -2.39702
# 4    0.1966    0.1825     0.1913     0.2021  29.027037 -2.39702
